# %%
import csv



files = ["results/results_MUC/first-few/en/CEAF-REE-greedy.csv", "results/results_MUC/random-few/en/CEAF-REE-greedy.csv", "results/results_MUC/first-few/en/CEAF-RME-greedy.csv", "results/results_MUC/random-few/en/CEAF-RME-greedy.csv"]
data = []
for file in files:
    with open(file, 'r') as f:
        reader = csv.reader(f)
        header = next(reader)
        rows = list(reader)
        if "REE" in file:
            col_index = header.index("micro_avg")
        else:
            col_index = header.index("f1")
        iter = 0
        file_data = []
        prev_k = -1
        for row in rows:
            k = int(row[0])
            file_data.append(row[col_index])
            while k - 1 != prev_k:
                prev_k +=1
                file_data.append(row[col_index])
            prev_k = k
        data.append(file_data)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 8
#       6 data = []
#       7 for file in files:
# ----> 8     with open(file, 'r') as f:
#       9         reader = csv.reader(f)
#      10         header = next(reader)
#
# File /scicomp/builds/Rocky/8.7/Common/software/Anaconda3/2023.03-1/lib/python3.10/site-packages/IPython/core/interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     275 if file in {0, 1, 2}:
#     276     raise ValueError(
#     277         f"IPython won't let you open fd={file} by default "
#     278         "as it is likely to crash IPython. If you know what you are doing, "
#     279         "you can use builtins' open."
#     280     )
# --> 282 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'results_MUC/random-few/en/CEAF-REE-greedy.csv'

# %%
for dat in data:
    print(len(dat))
    print(data)
# Out:
# 61
# ...

# %%
import matplotlib.pyplot as plt


tags = ["CEAF-REE F", "CEAF-REE R", "CEAF-RME F", "CEAF-RME R"]

# Plot the results from the 4 CSV files
plt.figure(figsize=(10, 6))
ks = list(range(0,61))


# Plot each file's data
for i, tag in enumerate(tags):
    plt.plot(ks, [float(score) for score in data[i]], marker='o', label=tag)

plt.xlabel('Few-shot k')
plt.ylabel('Micro Average F1 Score')
plt.title('Micro Average F1 Score vs Few-shot k for Different Files')
plt.legend()
plt.grid(True)
plt.show()

# %%
import csv


files = ["results/results_MUC/random-few/en/CEAF-RME-greedy.csv", "results/results_MUC/random-few/ar/CEAF-RME-greedy.csv", "results/results_MUC/random-few/fa/CEAF-RME-greedy.csv", "results/results_MUC/random-few/ko/CEAF-RME-greedy.csv", "results/results_MUC/random-few/ru/CEAF-RME-greedy.csv", "results/results_MUC/random-few/zh/CEAF-RME-greedy.csv"]
data = []
for file in files:
    with open(file, 'r') as f:
        reader = csv.reader(f)
        header = next(reader)
        rows = list(reader)
        if "REE" in file:
            col_index = header.index("micro_avg")
        else:
            col_index = header.index("f1")
        iter = 0
        file_data = []
        prev_k = -1
        for row in rows:
            k = int(row[0])
            file_data.append(row[col_index])
            while k - 1 != prev_k:
                prev_k +=1
                file_data.append(row[col_index])
            prev_k = k
        data.append(file_data)

# %%
import matplotlib.pyplot as plt

tags = ["English", "Arabic", "Farsi", "Korean", "Russian", "Chinese"]

# Plot the results from the 4 CSV files
plt.figure(figsize=(10, 6))
ks = list(range(0,61))


# Plot each file's data
for i, tag in enumerate(tags):
    plt.plot(ks, [float(score) for score in data[i]], marker='o', label=tag)

plt.xlabel('Random Few-shot k')
plt.ylabel('RME Micro Average F1 Score')
plt.title('RME Micro Average F1 Score vs Random Few-shot k for Different Languages')
plt.legend()
plt.grid(True)
plt.show()

# %%
import csv

files = ["results/results_MUC_simplified/random-few/en/CEAF-RME-greedy.csv", "results/results_MUC/random-few/en/CEAF-RME-greedy.csv", "results/results_MUC_simplified_post/random-few/en/CEAF-RME-greedy.csv"]
data = []
for file in files:
    with open(file, 'r') as f:
        reader = csv.reader(f)
        header = next(reader)
        rows = list(reader)
        if "REE" in file:
            col_index = header.index("micro_avg")
        else:
            col_index = header.index("f1")
        iter = 0
        file_data = []
        prev_k = -1
        for row in rows:
            k = int(row[0])
            file_data.append(row[col_index])
            while k - 1 != prev_k:
                prev_k +=1
                file_data.append(row[col_index])
            prev_k = k
        data.append(file_data)

# %%
import matplotlib.pyplot as plt

tags = ["English_Simplified_R", "English_Original_R","English_Simplified_Post_R"]

# Plot the results from the 4 CSV files
plt.figure(figsize=(10, 6))
ks = list(range(0,61))


# Plot each file's data
for i, tag in enumerate(tags):
    plt.plot(ks, [float(score) for score in data[i]], marker='o', label=tag)

plt.xlabel('First Few-shot k')
plt.ylabel('RME Micro Average F1 Score')
plt.title('RME Micro Average F1 Score vs Random Few-shot k for Simplified vs Original English')
plt.legend()
plt.grid(True)
plt.show()

# %%
import csv


files = ["results/results_MUC_simplified/random-few/en/CEAF-RME-greedy.csv", "results/results_MUC_simplified/random-few/ar/CEAF-RME-greedy.csv", "results/results_MUC_simplified/random-few/fa/CEAF-RME-greedy.csv", "results/results_MUC_simplified/random-few/ko/CEAF-RME-greedy.csv", "results/results_MUC_simplified/random-few/ru/CEAF-RME-greedy.csv", "results/results_MUC_simplified/random-few/zh/CEAF-RME-greedy.csv"]
data = []
for file in files:
    with open(file, 'r') as f:
        reader = csv.reader(f)
        header = next(reader)
        rows = list(reader)
        if "REE" in file:
            col_index = header.index("micro_avg")
        else:
            col_index = header.index("f1")
        iter = 0
        file_data = []
        prev_k = -1
        for row in rows:
            k = int(row[0])
            file_data.append(row[col_index])
            while k - 1 != prev_k:
                prev_k +=1
                file_data.append(row[col_index])
            prev_k = k
        data.append(file_data)

# %%
import matplotlib.pyplot as plt

tags = ["English", "Arabic", "Farsi", "Korean", "Russian", "Chinese"]

# Plot the results from the 4 CSV files
plt.figure(figsize=(10, 6))
ks = list(range(0,61))


# Plot each file's data
for i, tag in enumerate(tags):
    plt.plot(ks, [float(score) for score in data[i]], marker='o', label=tag)

plt.xlabel('Random Few-shot k')
plt.ylabel('RME Micro Average F1 Score')
plt.title('RME Micro Average F1 Score vs Random Few-shot k for Different Languages (Simplified version )')
plt.legend()
plt.grid(True)
plt.show()

# %%
import csv


files = ["results/results_MUC_simplified_post/random-few/en/CEAF-RME-greedy.csv", "results/results_MUC_simplified_post/random-few/ar/CEAF-RME-greedy.csv", "results/results_MUC_simplified_post/random-few/fa/CEAF-RME-greedy.csv", "results/results_MUC_simplified_post/random-few/ko/CEAF-RME-greedy.csv", "results/results_MUC_simplified_post/random-few/ru/CEAF-RME-greedy.csv", "results/results_MUC_simplified_post/random-few/zh/CEAF-RME-greedy.csv"]
data = []
for file in files:
    with open(file, 'r') as f:
        reader = csv.reader(f)
        header = next(reader)
        rows = list(reader)
        if "REE" in file:
            col_index = header.index("micro_avg")
        else:
            col_index = header.index("f1")
        iter = 0
        file_data = []
        prev_k = -1
        for row in rows:
            k = int(row[0])
            file_data.append(row[col_index])
            while k - 1 != prev_k:
                prev_k +=1
                file_data.append(row[col_index])
            prev_k = k
        data.append(file_data)

# %%
import matplotlib.pyplot as plt

tags = ["English", "Arabic", "Farsi", "Korean", "Russian", "Chinese"]

# Plot the results from the 4 CSV files
plt.figure(figsize=(10, 6))
ks = list(range(0,61))


# Plot each file's data
for i, tag in enumerate(tags):
    plt.plot(ks, [float(score) for score in data[i]], marker='o', label=tag)

plt.xlabel('Random Few-shot k')
plt.ylabel('RME Micro Average F1 Score')
plt.title('RME Micro Average F1 Score vs Random Few-shot k for Different Languages (Simplified version )')
plt.legend()
plt.grid(True)
plt.show()
